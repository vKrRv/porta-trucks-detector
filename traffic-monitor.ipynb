# %%
import json
import datetime
import os
import cv2
import numpy as np
from ultralytics import YOLO
from collections import defaultdict

# ============= 1. FILE PATHS =============
USER_HOME = os.path.expanduser("~")
DESKTOP_PATH = os.path.join(USER_HOME, "Desktop")
OUTPUT_FOLDER = os.path.join(DESKTOP_PATH, "heavy_truck_crops")
JSON_OUTPUT_PATH = os.path.join(DESKTOP_PATH, "road_status.json")

# MODEL: YOLO11 Extra Large (Maximum Accuracy)
MODEL_PATH = 'yolo11x.pt' 
VIDEO_PATH = '/Users/mohammadrebh/Desktop/2026-02-10 02.46.45.mp4'

# ============= 2. CONFIGURATION =============
CONFIDENCE_THRESHOLD = 0.2  
LINE_POSITION = 0.5         
IOU_THRESHOLD = 0.5
HEAVY_SIZE_THRESHOLD = 40000 

if not os.path.exists(OUTPUT_FOLDER): os.makedirs(OUTPUT_FOLDER)

# ============= 3. TRAFFIC LOGIC =============
def classify_traffic(total_vehicles, heavy_count, current_hour):
    if 8 <= current_hour < 14:
        if total_vehicles > 45 or heavy_count > 5: return "CONGESTED", "HALT_HEAVY_PERMITS"
        elif total_vehicles > 30 or heavy_count > 2: return "MODERATE", "LIMIT_HEAVY_PERMITS"
        else: return "NORMAL", "ALLOW_PERMITS"
    else:
        if total_vehicles > 35: return "MODERATE", "LIMIT_PERMITS"
        else: return "NORMAL", "ALLOW_PERMITS"

# ============= 4. MAIN EXECUTION =============
def main():
    print(f"🔄 Loading Best Model: {MODEL_PATH} ...")
    model = YOLO(MODEL_PATH)
    
    # 2=Car, 3=Motorcycle, 5=Bus, 7=Truck
    TARGET_CLASSES = [2, 3, 5, 7]
    
    cap = cv2.VideoCapture(VIDEO_PATH)
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)
    
    line_y = int(height * LINE_POSITION)
    
    track_history = defaultdict(lambda: [])
    counts = {"Car": 0, "Motorcycle": 0, "Bus": 0, "Truck": 0, "Heavy Truck": 0}
    crossed_ids = set()
    
    frames_processed = 0
    save_interval = int(fps * 60 * 0.5) 
    
    previous_total = 0
    previous_heavy = 0
    current_status = "CALCULATING..."

    def save_json(note=""):
        nonlocal previous_total, previous_heavy
        current_total = sum(counts.values())
        current_heavy = counts["Heavy Truck"] + counts["Bus"]
        
        interval_total = current_total - previous_total
        interval_heavy = current_heavy - previous_heavy
        
        status, rec = classify_traffic(interval_total, interval_heavy, datetime.datetime.now().hour)
        
        payload = {
            "timestamp": datetime.datetime.now().isoformat(),
            "total_since_start": current_total, # Added useful stat
            "interval_count": interval_total,
            "interval_heavy": interval_heavy,
            "status": status,
            "recommendation": rec,
            "note": note
        }
        
        try:
            if os.path.exists(JSON_OUTPUT_PATH):
                with open(JSON_OUTPUT_PATH, 'r') as f: history = json.load(f)
            else: history = []
        except: history = []
        
        history.append(payload)
        with open(JSON_OUTPUT_PATH, 'w') as f: json.dump(history, f, indent=4)
        
        previous_total = current_total
        previous_heavy = current_heavy
        return status

    print("🚀 STARTED! Press 'ESC' to quit.")

    while cap.isOpened():
        success, frame = cap.read()
        if not success: break
        
        frames_processed += 1
        
        # Track
        results = model.track(frame, persist=True, conf=CONFIDENCE_THRESHOLD, iou=IOU_THRESHOLD, classes=TARGET_CLASSES, verbose=False)
        
        boxes = results[0].boxes
        if boxes.id is not None:
            track_ids = boxes.id.int().cpu().tolist()
            cls_ids = boxes.cls.int().cpu().tolist()
            xyxys = boxes.xyxy.cpu().tolist()
            
            for box, track_id, cls_id in zip(xyxys, track_ids, cls_ids):
                x1, y1, x2, y2 = map(int, box)
                w_box = x2 - x1
                h_box = y2 - y1
                area = w_box * h_box
                current_y = y2 
                
                # Classification Logic
                if cls_id == 7: 
                    if area > HEAVY_SIZE_THRESHOLD:
                        final_class = "Heavy Truck"
                        display_color = (0, 0, 255) 
                    else:
                        final_class = "Truck"
                        display_color = (0, 255, 255) 
                elif cls_id == 5:
                    final_class = "Bus"
                    display_color = (0, 0, 255) 
                elif cls_id == 2:
                    final_class = "Car"
                    display_color = (0, 255, 0)
                elif cls_id == 3:
                    final_class = "Motorcycle"
                    display_color = (0, 255, 0)
                else:
                    final_class = "Unknown"
                    display_color = (255, 255, 255)

                # Count Logic
                track = track_history[track_id]
                track.append(current_y)
                if len(track) > 30: track.pop(0)
                
                if len(track) >= 2:
                    prev_y = track[-2]
                    if prev_y < line_y and current_y > line_y:
                        if track_id not in crossed_ids:
                            crossed_ids.add(track_id)
                            counts[final_class] += 1
                            
                            if final_class == "Heavy Truck":
                                crop = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]
                                cv2.imwrite(f"{OUTPUT_FOLDER}/heavy_{track_id}.jpg", crop)
                                print(f"📸 SAVED HEAVY TRUCK #{track_id}")
                            
                            print(f"✅ COUNTED: #{track_id} as {final_class}")

                cv2.rectangle(frame, (x1, y1), (x2, y2), display_color, 2)
                cv2.putText(frame, f"#{track_id} {final_class}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, display_color, 2)

        cv2.line(frame, (0, line_y), (width, line_y), (0, 255, 255), 2)
        
        # --- SIDEBAR UI ---
        # 1. Background
        cv2.rectangle(frame, (10, 10), (300, 400), (0, 0, 0), -1)
        
        # 2. Header
        cv2.putText(frame, "TRAFFIC MONITOR", (20, 35), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv2.putText(frame, f"STATUS: {current_status}", (20, 65), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
        
        # 3. SEPARATOR LINE
        cv2.line(frame, (20, 80), (290, 80), (100, 100, 100), 1)

        # 4. TOTAL COUNTER (NEW!)
        total_count = sum(counts.values())
        cv2.putText(frame, f"TOTAL: {total_count}", (20, 110), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)

        # 5. SEPARATOR LINE
        cv2.line(frame, (20, 130), (290, 130), (100, 100, 100), 1)
        
        # 6. Breakdown
        y_pos = 160
        order = ["Heavy Truck", "Bus", "Truck", "Car", "Motorcycle"]
        for key in order:
            count = counts[key]
            if key in ["Heavy Truck", "Bus"]: c = (0, 0, 255)
            elif key == "Truck": c = (0, 255, 255)
            else: c = (0, 255, 0)
            
            cv2.putText(frame, f"{key}: {count}", (20, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 0.7, c, 2)
            y_pos += 40

        if frames_processed % save_interval == 0:
            current_status = save_json() cv2.imshow("YOLO11 Smart Tracker", frame)
        if cv2.waitKey(1) & 0xFF == 27: break

    cap.release()
    cv2.destroyAllWindows()
    save_json("END")

if __name__ == "__main__":
    main()
# Out:
# 🔄 Loading Best Model: yolo11x.pt ...
# 🚀 STARTED! Press 'ESC' to quit.
# ✅ COUNTED: #1 as Car
# ✅ COUNTED: #8 as Car
# ✅ COUNTED: #10 as Car
# ✅ COUNTED: #14 as Car
# ✅ COUNTED: #19 as Car
# ✅ COUNTED: #21 as Car
# ✅ COUNTED: #22 as Car
# ✅ COUNTED: #24 as Car
# ✅ COUNTED: #26 as Car
# ✅ COUNTED: #33 as Car
# ✅ COUNTED: #35 as Car
# ✅ COUNTED: #36 as Car
# ✅ COUNTED: #37 as Car
# ✅ COUNTED: #38 as Car
# ✅ COUNTED: #40 as Car
# ✅ COUNTED: #42 as Car
# ✅ COUNTED: #55 as Car
# ✅ COUNTED: #58 as Car
# ✅ COUNTED: #60 as Car
# ✅ COUNTED: #63 as Car
# ✅ COUNTED: #69 as Car
# 📸 SAVED HEAVY TRUCK #70
# ✅ COUNTED: #70 as Heavy Truck
# ✅ COUNTED: #80 as Car
# ✅ COUNTED: #83 as Car
# 📸 SAVED HEAVY TRUCK #81
# ✅ COUNTED: #81 as Heavy Truck
# ✅ COUNTED: #88 as Car
# ✅ COUNTED: #89 as Car
# ✅ COUNTED: #90 as Car
# ✅ COUNTED: #91 as Car
# ✅ COUNTED: #92 as Car
# ✅ COUNTED: #93 as Car
# ✅ COUNTED: #97 as Car
# ✅ COUNTED: #98 as Car
# ✅ COUNTED: #105 as Car
# ✅ COUNTED: #106 as Car
# ✅ COUNTED: #107 as Car
# ✅ COUNTED: #108 as Car
# ✅ COUNTED: #109 as Car
# ✅ COUNTED: #111 as Car
# ✅ COUNTED: #112 as Car
# ✅ COUNTED: #121 as Car
# ✅ COUNTED: #124 as Car
# ✅ COUNTED: #129 as Car
# ✅ COUNTED: #128 as Car
# ✅ COUNTED: #130 as Car
# ✅ COUNTED: #135 as Car
# ✅ COUNTED: #143 as Car
# ✅ COUNTED: #144 as Car
# ✅ COUNTED: #145 as Car
# ✅ COUNTED: #147 as Car
# ✅ COUNTED: #150 as Car
# ✅ COUNTED: #149 as Car
# ✅ COUNTED: #152 as Bus
# ✅ COUNTED: #163 as Car
# ✅ COUNTED: #165 as Car
# ✅ COUNTED: #175 as Car
# ✅ COUNTED: #174 as Car
# ✅ COUNTED: #176 as Car
# ✅ COUNTED: #182 as Car
# ✅ COUNTED: #180 as Car
# ✅ COUNTED: #190 as Car
# ✅ COUNTED: #193 as Car
# ✅ COUNTED: #199 as Car
# 📸 SAVED HEAVY TRUCK #200
# ✅ COUNTED: #200 as Heavy Truck
# ✅ COUNTED: #202 as Car
# ✅ COUNTED: #206 as Car
# ✅ COUNTED: #213 as Car
# ✅ COUNTED: #214 as Car
# ✅ COUNTED: #218 as Car
# ✅ COUNTED: #219 as Car
# ✅ COUNTED: #220 as Car
# ✅ COUNTED: #225 as Car
# 📸 SAVED HEAVY TRUCK #230
# ✅ COUNTED: #230 as Heavy Truck
# ✅ COUNTED: #241 as Car
# ✅ COUNTED: #229 as Car
# ✅ COUNTED: #246 as Car
# 📸 SAVED HEAVY TRUCK #242
# ✅ COUNTED: #242 as Heavy Truck
# ✅ COUNTED: #256 as Car
# ✅ COUNTED: #260 as Car
# ✅ COUNTED: #261 as Car
# ✅ COUNTED: #263 as Car
# ✅ COUNTED: #266 as Car
# ✅ COUNTED: #268 as Car
# ✅ COUNTED: #272 as Car
# ✅ COUNTED: #276 as Car
# ✅ COUNTED: #274 as Car
# 📸 SAVED HEAVY TRUCK #279
# ✅ COUNTED: #279 as Heavy Truck
# ✅ COUNTED: #278 as Car
# ✅ COUNTED: #284 as Car
# ✅ COUNTED: #288 as Car
# ✅ COUNTED: #291 as Car
# ✅ COUNTED: #289 as Car
# ✅ COUNTED: #297 as Car
# ✅ COUNTED: #296 as Car
# ✅ COUNTED: #304 as Car
# ✅ COUNTED: #305 as Car
# ✅ COUNTED: #311 as Car
# ✅ COUNTED: #317 as Car
# ✅ COUNTED: #332 as Car
# 📸 SAVED HEAVY TRUCK #334
# ✅ COUNTED: #334 as Heavy Truck
# ✅ COUNTED: #326 as Car
# ✅ COUNTED: #338 as Car
# ✅ COUNTED: #347 as Car
# ✅ COUNTED: #348 as Car
# ✅ COUNTED: #356 as Bus
# ✅ COUNTED: #359 as Car
# ✅ COUNTED: #362 as Car
# ✅ COUNTED: #366 as Car
# ✅ COUNTED: #372 as Car
# ✅ COUNTED: #370 as Car
# ✅ COUNTED: #373 as Car
# ✅ COUNTED: #379 as Car
# 📸 SAVED HEAVY TRUCK #375
# ✅ COUNTED: #375 as Heavy Truck
# ✅ COUNTED: #376 as Car
# ✅ COUNTED: #378 as Car
# ✅ COUNTED: #381 as Car
# ✅ COUNTED: #384 as Car
# ✅ COUNTED: #389 as Car
# ✅ COUNTED: #401 as Car
# ✅ COUNTED: #402 as Car
# ✅ COUNTED: #404 as Car
# ✅ COUNTED: #405 as Car
# ✅ COUNTED: #408 as Car
# ✅ COUNTED: #410 as Car
# ✅ COUNTED: #414 as Car
# ✅ COUNTED: #412 as Car
# ✅ COUNTED: #415 as Car
# ✅ COUNTED: #422 as Car
# ✅ COUNTED: #430 as Car
# ✅ COUNTED: #438 as Car
# ✅ COUNTED: #437 as Car
# ✅ COUNTED: #439 as Car
# ✅ COUNTED: #440 as Car
# ✅ COUNTED: #446 as Car
# ✅ COUNTED: #451 as Car
# ✅ COUNTED: #453 as Car
# ✅ COUNTED: #454 as Car
# ✅ COUNTED: #456 as Car
# ✅ COUNTED: #461 as Car
# ✅ COUNTED: #466 as Car
# ✅ COUNTED: #464 as Car
# ✅ COUNTED: #467 as Car
# ✅ COUNTED: #470 as Car
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from ultralytics import YOLO
import cv2

# Load your model
model = YOLO('/Users/mohammadrebh/Desktop/vehicle_classifier/truker_train_run/weights/best.pt')

# Load the video
video_path = '/Users/mohammadrebh/Desktop/2026-02-10 02.46.45.mp4'
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()

if ret:
    # Run inference with LOW confidence and SHOW logic
    results = model(frame, conf=0.1, imgsz=1280) 
    
    # Show what the model sees natively
    res_plotted = results[0].plot()
    cv2.imshow("DEBUG VIEW", res_plotted)
    print("Press any key to close...")
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Could not read video")
# Out:
# 0: 736x1280 1 Auto, 1 Truck, 95.1ms
# Speed: 4.7ms preprocess, 95.1ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
# Press any key to close...

# %%
from ultralytics import YOLO
import cv2
import os

# PATHS
MODEL_PATH = '/Users/mohammadrebh/Desktop/vehicle_classifier/truker_train_run/weights/best.pt'
VIDEO_PATH = '/Users/mohammadrebh/Desktop/2026-02-10 02.46.45.mp4'

# Load Model
model = YOLO(MODEL_PATH)

# PRINT THE CLASSES YOUR MODEL KNOWS
print("------------------------------------------------")
print(f"📋 YOUR MODEL'S CLASSES: {model.names}")
print("------------------------------------------------")

cap = cv2.VideoCapture(VIDEO_PATH)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret: break

    # Run inference at DEFAULT size (640) to be safe
    # conf=0.1 means "Show me anything you are even 10% sure about"
    results = model(frame, conf=0.1) 
    
    # Plot results on the frame
    annotated_frame = results[0].plot()

    cv2.imshow("DIAGNOSTIC VIEW - Press 'q' to quit", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'): break

cap.release()
cv2.destroyAllWindows()
# Out:
# ------------------------------------------------
# 📋 YOUR MODEL'S CLASSES: {0: 'Motorcycle', 1: 'Auto', 2: 'Car', 3: 'Bus', 4: 'LCV', 5: 'Truck', 6: 'Tractor', 7: 'Heavy Truck'}
# ------------------------------------------------
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 63.1ms
# Speed: 1.4ms preprocess, 63.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Truck, 1 Heavy Truck, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 33.4ms
# Speed: 2.6ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 31.3ms
# Speed: 1.3ms preprocess, 31.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 34.0ms
# Speed: 1.2ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 31.9ms
# Speed: 1.5ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 36.2ms
# Speed: 1.6ms preprocess, 36.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 2 Heavy Trucks, 33.2ms
# Speed: 1.3ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Heavy Trucks, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Heavy Trucks, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 2 Heavy Trucks, 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Trucks, 2 Heavy Trucks, 33.0ms
# Speed: 1.2ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 1 Heavy Truck, 39.1ms
# Speed: 13.5ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 34.3ms
# Speed: 1.7ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 32.0ms
# Speed: 1.6ms preprocess, 32.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 1 Heavy Truck, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 2 Heavy Trucks, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Heavy Truck, 31.4ms
# Speed: 1.2ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.0ms
# Speed: 1.3ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.2ms
# Speed: 1.3ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Bus, 1 Truck, 1 Heavy Truck, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 34.5ms
# Speed: 1.4ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 32.3ms
# Speed: 1.3ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 32.7ms
# Speed: 1.2ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 3 Trucks, 2 Heavy Trucks, 52.5ms
# Speed: 9.0ms preprocess, 52.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 2 Heavy Trucks, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Heavy Truck, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 33.4ms
# Speed: 1.4ms preprocess, 33.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Heavy Truck, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.6ms
# Speed: 1.8ms preprocess, 30.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.2ms
# Speed: 1.3ms preprocess, 31.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 30.7ms
# Speed: 1.4ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.5ms
# Speed: 1.7ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.6ms
# Speed: 1.4ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.7ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.4ms
# Speed: 1.2ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 35.1ms
# Speed: 1.8ms preprocess, 35.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 31.9ms
# Speed: 1.6ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 30.7ms
# Speed: 1.5ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 32.3ms
# Speed: 1.4ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 36.3ms
# Speed: 1.6ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 31.0ms
# Speed: 1.4ms preprocess, 31.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Heavy Trucks, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 2 Heavy Trucks, 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Truck, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 34.3ms
# Speed: 1.4ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 32.2ms
# Speed: 1.5ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 32.8ms
# Speed: 1.4ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 31.5ms
# Speed: 1.3ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 2 Heavy Trucks, 32.8ms
# Speed: 1.3ms preprocess, 32.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Heavy Truck, 31.9ms
# Speed: 1.4ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Heavy Truck, 33.3ms
# Speed: 1.2ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Bus, 1 Heavy Truck, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 34.5ms
# Speed: 1.6ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 4 Cars, 1 Truck, 1 Heavy Truck, 61.1ms
# Speed: 1.5ms preprocess, 61.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Cars, 1 Truck, 33.6ms
# Speed: 1.4ms preprocess, 33.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 1 Bus, 1 Truck, 32.0ms
# Speed: 1.4ms preprocess, 32.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 1 Truck, 32.3ms
# Speed: 1.5ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 32.9ms
# Speed: 1.4ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 2 Heavy Trucks, 34.5ms
# Speed: 1.3ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 2 Trucks, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 32.1ms
# Speed: 1.4ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 30.3ms
# Speed: 1.5ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 31.9ms
# Speed: 1.4ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 31.1ms
# Speed: 1.4ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 34.3ms
# Speed: 1.3ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Autos, 1 Car, 41.2ms
# Speed: 16.4ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 31.9ms
# Speed: 1.6ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Heavy Truck, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Truck, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 32.7ms
# Speed: 1.4ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 1 Heavy Truck, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 1 Car, 1 Truck, 1 Heavy Truck, 31.7ms
# Speed: 1.6ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Heavy Truck, 34.3ms
# Speed: 1.3ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 31.6ms
# Speed: 1.2ms preprocess, 31.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 31.5ms
# Speed: 1.4ms preprocess, 31.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 1 Heavy Truck, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 2 Cars, 2 Trucks, 2 Heavy Trucks, 40.5ms
# Speed: 1.5ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 3 Heavy Trucks, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 3 Cars, 1 Truck, 2 Heavy Trucks, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 1 Heavy Truck, 34.7ms
# Speed: 1.6ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 2 Heavy Trucks, 60.0ms
# Speed: 5.0ms preprocess, 60.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 1 Car, 2 Trucks, 2 Heavy Trucks, 34.5ms
# Speed: 1.6ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 1 Heavy Truck, 32.0ms
# Speed: 1.5ms preprocess, 32.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 3 Trucks, 2 Heavy Trucks, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 1 Heavy Truck, 31.7ms
# Speed: 1.3ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 1 Heavy Truck, 34.6ms
# Speed: 1.2ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 1 Heavy Truck, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 1 Heavy Truck, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Heavy Truck, 31.9ms
# Speed: 1.5ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Heavy Truck, 34.2ms
# Speed: 1.4ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Heavy Truck, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 1 Heavy Truck, 34.9ms
# Speed: 1.3ms preprocess, 34.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 3 Cars, 1 Bus, 2 Heavy Trucks, 33.8ms
# Speed: 1.3ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 31.4ms
# Speed: 1.6ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Heavy Truck, 31.5ms
# Speed: 1.2ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Heavy Truck, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 4 Cars, 1 Heavy Truck, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 3 Cars, 1 Heavy Truck, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Heavy Truck, 35.0ms
# Speed: 1.4ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 3 Trucks, 2 Heavy Trucks, 32.5ms
# Speed: 1.4ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 3 Trucks, 2 Heavy Trucks, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 2 Trucks, 1 Heavy Truck, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Truck, 1 Heavy Truck, 31.8ms
# Speed: 1.5ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Truck, 1 Heavy Truck, 32.3ms
# Speed: 1.5ms preprocess, 32.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 32.1ms
# Speed: 1.5ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 34.3ms
# Speed: 1.4ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 32.8ms
# Speed: 1.4ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 35.6ms
# Speed: 1.9ms preprocess, 35.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 32.5ms
# Speed: 1.3ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 32.5ms
# Speed: 1.2ms preprocess, 32.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 31.5ms
# Speed: 1.4ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 61.1ms
# Speed: 1.3ms preprocess, 61.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 32.4ms
# Speed: 1.4ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 32.4ms
# Speed: 1.3ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 33.0ms
# Speed: 1.3ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 32.2ms
# Speed: 1.5ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 33.2ms
# Speed: 1.3ms preprocess, 33.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 33.1ms
# Speed: 2.1ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 34.0ms
# Speed: 2.4ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 34.7ms
# Speed: 1.9ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 2 Trucks, 35.2ms
# Speed: 1.3ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 32.5ms
# Speed: 1.3ms preprocess, 32.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 1 Truck, 1 Heavy Truck, 32.4ms
# Speed: 1.4ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Truck, 1 Heavy Truck, 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Truck, 1 Heavy Truck, 38.7ms
# Speed: 12.8ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Truck, 33.6ms
# Speed: 1.4ms preprocess, 33.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Truck, 1 Heavy Truck, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 31.0ms
# Speed: 1.6ms preprocess, 31.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 2 Heavy Trucks, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 30.4ms
# Speed: 1.5ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Bus, 2 Trucks, 1 Heavy Truck, 30.3ms
# Speed: 1.6ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Truck, 2 Heavy Trucks, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 2 Heavy Trucks, 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Bus, 2 Heavy Trucks, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Bus, 2 Heavy Trucks, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Bus, 1 Truck, 2 Heavy Trucks, 31.8ms
# Speed: 1.4ms preprocess, 31.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Bus, 3 Heavy Trucks, 35.3ms
# Speed: 1.7ms preprocess, 35.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 2 Heavy Trucks, 34.7ms
# Speed: 1.4ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.8ms
# Speed: 1.4ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Truck, 2 Heavy Trucks, 33.4ms
# Speed: 1.6ms preprocess, 33.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 63.2ms
# Speed: 1.3ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 2 Trucks, 34.1ms
# Speed: 1.3ms preprocess, 34.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 2 Trucks, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Trucks, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Trucks, 2 Heavy Trucks, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 2 Heavy Trucks, 31.8ms
# Speed: 1.4ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 2 Heavy Trucks, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 32.3ms
# Speed: 2.2ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 2 Heavy Trucks, 33.1ms
# Speed: 1.6ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 2 Heavy Trucks, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 2 Heavy Trucks, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 2 Heavy Trucks, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 4 Trucks, 1 Heavy Truck, 38.7ms
# Speed: 9.4ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 1 Truck, 35.3ms
# Speed: 1.5ms preprocess, 35.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Trucks, 1 Heavy Truck, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Bus, 1 Truck, 1 Heavy Truck, 31.7ms
# Speed: 1.4ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Heavy Truck, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Truck, 31.9ms
# Speed: 1.3ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Heavy Truck, 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 32.4ms
# Speed: 1.3ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Bus, 1 Heavy Truck, 32.4ms
# Speed: 1.4ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Bus, 1 Truck, 1 Heavy Truck, 33.1ms
# Speed: 1.3ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 32.0ms
# Speed: 1.5ms preprocess, 32.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Trucks, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Trucks, 34.2ms
# Speed: 1.6ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 1 Heavy Truck, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Truck, 1 Heavy Truck, 30.7ms
# Speed: 2.2ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 2 Heavy Trucks, 59.5ms
# Speed: 1.5ms preprocess, 59.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Trucks, 3 Heavy Trucks, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 3 Heavy Trucks, 33.7ms
# Speed: 1.2ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Trucks, 3 Heavy Trucks, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Trucks, 1 Heavy Truck, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Bus, 1 Heavy Truck, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 2 Trucks, 3 Heavy Trucks, 34.3ms
# Speed: 2.1ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 1 Truck, 3 Heavy Trucks, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 2 Heavy Trucks, 33.0ms
# Speed: 1.3ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 3 Trucks, 3 Heavy Trucks, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Bus, 1 Truck, 3 Heavy Trucks, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Trucks, 1 Heavy Truck, 32.5ms
# Speed: 1.2ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Bus, 1 Truck, 2 Heavy Trucks, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 34.8ms
# Speed: 2.4ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 34.5ms
# Speed: 1.3ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 2 Heavy Trucks, 35.5ms
# Speed: 2.1ms preprocess, 35.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 3 Heavy Trucks, 62.3ms
# Speed: 1.5ms preprocess, 62.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 31.3ms
# Speed: 1.4ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 2 Heavy Trucks, 31.8ms
# Speed: 1.4ms preprocess, 31.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.6ms
# Speed: 1.4ms preprocess, 32.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.2ms
# Speed: 1.2ms preprocess, 33.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.7ms
# Speed: 1.2ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Truck, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 34.7ms
# Speed: 1.4ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 33.2ms
# Speed: 1.3ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 35.2ms
# Speed: 1.9ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 3 Cars, 1 Truck, 60.9ms
# Speed: 1.9ms preprocess, 60.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 3 Cars, 1 Truck, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Bus, 1 Truck, 1 Heavy Truck, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 35.0ms
# Speed: 1.8ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 2 Trucks, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 35.5ms
# Speed: 2.2ms preprocess, 35.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.4ms
# Speed: 1.4ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 39.2ms
# Speed: 1.4ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 37.1ms
# Speed: 1.7ms preprocess, 37.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 1 Heavy Truck, 34.6ms
# Speed: 1.5ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 34.6ms
# Speed: 1.9ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 44.9ms
# Speed: 1.3ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 1 Heavy Truck, 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 2 Heavy Trucks, 32.9ms
# Speed: 1.4ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Truck, 1 Heavy Truck, 32.1ms
# Speed: 1.4ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 2 Heavy Trucks, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Bus, 1 Truck, 3 Heavy Trucks, 32.5ms
# Speed: 1.3ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 2 Cars, 1 Truck, 1 Heavy Truck, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 33.2ms
# ...
#
# 0: 384x640 2 Autos, 1 Car, 1 Heavy Truck, 31.8ms
# Speed: 1.4ms preprocess, 31.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Trucks, 2 Heavy Trucks, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 2 Cars, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 1 Heavy Truck, 32.8ms
# Speed: 1.4ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Heavy Truck, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Heavy Truck, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 Heavy Truck, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 34.2ms
# Speed: 1.4ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Bus, 1 Heavy Truck, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 2 Cars, 1 Bus, 1 Heavy Truck, 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Bus, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 34.3ms
# Speed: 2.2ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Heavy Truck, 32.3ms
# Speed: 1.5ms preprocess, 32.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 1 Car, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Autos, 2 Cars, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 34.4ms
# Speed: 1.8ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 32.9ms
# Speed: 1.4ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 66.1ms
# Speed: 1.4ms preprocess, 66.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 34.0ms
# Speed: 2.3ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 33.2ms
# Speed: 1.6ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 34.3ms
# Speed: 2.4ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 72.9ms
# Speed: 1.4ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Truck, 1 Heavy Truck, 33.3ms
# Speed: 1.8ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Heavy Truck, 31.8ms
# Speed: 1.5ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 2 Trucks, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 34.9ms
# Speed: 2.6ms preprocess, 34.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 1 Truck, 2 Heavy Trucks, 33.6ms
# Speed: 1.3ms preprocess, 33.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 2 Heavy Trucks, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 2 Heavy Trucks, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 1 Truck, 2 Heavy Trucks, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 62.9ms
# Speed: 1.3ms preprocess, 62.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Heavy Truck, 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 2 Heavy Trucks, 32.1ms
# Speed: 1.5ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Heavy Trucks, 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 3 Heavy Trucks, 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 2 Heavy Trucks, 33.1ms
# Speed: 1.6ms preprocess, 33.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 3 Heavy Trucks, 34.3ms
# Speed: 1.4ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 2 Heavy Trucks, 41.3ms
# Speed: 1.7ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Heavy Truck, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 2 Heavy Trucks, 33.3ms
# Speed: 1.3ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.8ms
# Speed: 1.3ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Heavy Truck, 48.3ms
# Speed: 1.7ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Bus, 1 Heavy Truck, 34.8ms
# Speed: 1.5ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Bus, 2 Heavy Trucks, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 2 Trucks, 31.1ms
# Speed: 1.8ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 2 Trucks, 1 Heavy Truck, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 1 Heavy Truck, 33.8ms
# Speed: 1.6ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 1 Truck, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 38.8ms
# Speed: 5.8ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 31.1ms
# Speed: 1.5ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 40.7ms
# Speed: 1.3ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Truck, 2 Heavy Trucks, 33.5ms
# Speed: 1.3ms preprocess, 33.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 1 Heavy Truck, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 2 Heavy Trucks, 33.1ms
# Speed: 1.2ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 2 Heavy Trucks, 41.9ms
# Speed: 1.5ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 2 Trucks, 2 Heavy Trucks, 32.6ms
# Speed: 1.4ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 3 Trucks, 3 Heavy Trucks, 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 3 Heavy Trucks, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Bus, 1 Truck, 2 Heavy Trucks, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 2 Heavy Trucks, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 2 Heavy Trucks, 39.4ms
# Speed: 5.7ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Trucks, 1 Heavy Truck, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Trucks, 3 Heavy Trucks, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 3 Trucks, 1 Heavy Truck, 34.7ms
# Speed: 1.8ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 2 Trucks, 1 Heavy Truck, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 2 Trucks, 32.9ms
# Speed: 1.4ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 3 Trucks, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 2 Cars, 1 Truck, 1 Heavy Truck, 31.1ms
# Speed: 1.6ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 3 Trucks, 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 2 Trucks, 1 Heavy Truck, 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Autos, 1 Car, 2 Trucks, 1 Heavy Truck, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 1 Car, 3 Trucks, 2 Heavy Trucks, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Autos, 2 Cars, 2 Trucks, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 2 Trucks, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 1 Bus, 1 Heavy Truck, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 2 Buss, 1 Heavy Truck, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Heavy Truck, 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 2 Cars, 2 Trucks, 1 Heavy Truck, 30.3ms
# Speed: 1.4ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Heavy Truck, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Cars, 1 Heavy Truck, 38.4ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Bus, 2 Trucks, 1 Heavy Truck, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 4 Cars, 1 Truck, 1 Heavy Truck, 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Cars, 1 Heavy Truck, 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 4 Cars, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 3 Cars, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 34.2ms
# Speed: 1.6ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Truck, 1 Heavy Truck, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Cars, 1 Truck, 35.0ms
# Speed: 2.6ms preprocess, 35.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 2 Trucks, 1 Heavy Truck, 32.4ms
# Speed: 1.2ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Truck, 60.7ms
# Speed: 1.4ms preprocess, 60.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Trucks, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Trucks, 1 Heavy Truck, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 Heavy Truck, 31.4ms
# Speed: 1.5ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 2.5ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heavy Truck, 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Truck, 63.0ms
# Speed: 1.3ms preprocess, 63.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
